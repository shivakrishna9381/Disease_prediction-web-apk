# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
dataset = pd.read_csv("stroke_data.csv")
dataset
# Out:
#        sex   age  hypertension  heart_disease  ever_married  work_type  \
# 0      1.0  63.0             0              1             1          4
# 1      1.0  42.0             0              1             1          4
# 2      0.0  61.0             0              0             1          4
# 3      1.0  41.0             1              0             1          3
# 4      1.0  85.0             0              0             1          4
# ...    ...   ...           ...            ...           ...        ...
# 40905  1.0  38.0             0              0             0          4
# 40906  0.0  53.0             0              0             1          4
# 40907  1.0  32.0             0              0             1          2
# 40908  1.0  42.0             0              0             1          3
# 40909  1.0  35.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
dataset_new = dataset.drop(columns = ["work_type", 'ever_married', 'Residence_type'])
dataset_new
# Out:
#        sex   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0      1.0  63.0             0              1             228.69  36.6
# 1      1.0  42.0             0              1             105.92  32.5
# 2      0.0  61.0             0              0             171.23  34.4
# 3      1.0  41.0             1              0             174.12  24.0
# 4      1.0  85.0             0              0             186.21  29.0
# ...    ...   ...           ...            ...                ...   ...
# 40905  1.0  38.0             0              0             120.94  29.7
# 40906  0.0  53.0             0              0              77.66  40.8
# 40907  1.0  32.0             0              0             231.95  33.2
# 40908  1.0  42.0             0              0             216.38  34.5
# 40909  1.0  35.0             0              0              95.01  28.0
#
#        smoking_status  stroke
# 0                   1       1
# 1                   0       1
# ...

# %%
dataset_new = dataset_new.dropna()

# %%
dataset_new.isnull().sum()
# Out:
# sex                  0
# age                  0
# hypertension         0
# heart_disease        0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
x = dataset_new.drop("stroke", axis = 1)
y = dataset_new['stroke']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 40905    0
# 40906    0
# 40907    0
# 40908    0
# 40909    0
# Name: stroke, Length: 40907, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=100, max_depth=None, random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9890002444390125
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      4112
#            1       0.98      1.00      0.99      4070
#
#     accuracy                           0.99      8182
#    macro avg       0.99      0.99      0.99      8182
# weighted avg       0.99      0.99      0.99      8182
#
# [[4024   88]
#  [   2 4068]]

# %%
import pickle
from sklearn.ensemble import RandomForestClassifier

# Assuming rf is your trained RandomForestClassifier model
with open('strokedet.pkl', 'wb') as file:
    pickle.dump(rf_model, file)
